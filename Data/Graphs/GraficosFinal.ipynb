# %%
# %matplotlib notebook
import numpy as np
from matplotlib import pyplot as plt

# %%
TOI_pin=np.loadtxt("TOI.csv",delimiter=",",skiprows=0,usecols=[0])
TOI_pflow=np.loadtxt("TOI.csv",delimiter=",",skiprows=0,usecols=[1])
TOI_pfhigh=np.loadtxt("TOI.csv",delimiter=",",skiprows=0,usecols=[2])
TOI_p3low=np.loadtxt("TOI.csv",delimiter=",",skiprows=0,usecols=[3])
TOI_p3high=np.loadtxt("TOI.csv",delimiter=",",skiprows=0,usecols=[4])

# %%
plt.figure()
plt.grid()
plt.xticks(np.arange(-13, 20, step=2))
plt.yticks(np.arange(-50, 50, step=10))
plt.xlabel('Potencia de entrada [dBm]')
plt.ylabel('Potencia de salida [dBm]')
plt.plot(TOI_pin,TOI_pflow,linewidth=3,label='Frecuencia fundamental')
plt.plot(TOI_pin,TOI_p3low,linewidth=3,label='Producto de 3er orden')
#plt.plot(TOI_pin,TOI_p3high)
TOI_pinext=np.linspace(-13,15,100)
plt.plot(TOI_pinext,0.96710*TOI_pinext+14.402,linestyle='dashed',label='Ajuste pendiente 1')
plt.plot(TOI_pinext,3.3653*TOI_pinext-10.1389,linestyle='dashed',label='Ajuste pendiente 3')
#plt.plot(TOI_pinext,3.369357143*TOI_pinext-8.385535714)
ip3in=10.233
ip3out=24.2985
plt.scatter(ip3in,ip3out,color='black',label='$IP_3$')
plt.legend()
plt.tight_layout()
plt.show()
plt.savefig('Amp2Tone.pdf',bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
p1db_pin=np.loadtxt("P1dB.txt",delimiter="\t",skiprows=0,usecols=[0])
p1db_pout=np.loadtxt("P1dB.txt",delimiter="\t",skiprows=0,usecols=[1])

# %%
plt.figure()
plt.grid()
plt.xticks(np.arange(-10, 20, step=1))
plt.yticks(np.arange(4, 20, step=1))
plt.xlabel('Potencia de entrada [dBm]')
plt.ylabel('Potencia de salida [dBm]')
plt.plot(p1db_pin,p1db_pout,linewidth=3,label='Frecuencia fundamental')
p1db_pinext=np.linspace(-10,2,100)
plt.plot(p1db_pinext,1.019764316*p1db_pinext+14.85004651,linestyle='dashed',label='Ajuste pendiente 1')
#plt.plot(p1db_pinext,1.019764316*p1db_pinext+14.85004651-1,linestyle='dashed')
p1dBin=-1.11287
p1dBout=12.7151
plt.scatter(p1dBin,p1dBout,label='$P_{1 dB}$',color='red')
plt.tight_layout()
plt.legend()
plt.show()
plt.savefig('Amp1Tone.pdf',bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
filts21_freq=np.loadtxt("FiltS21.txt",delimiter="\t",skiprows=0,usecols=[0])
filts21_dB=np.loadtxt("FiltS21.txt",delimiter="\t",skiprows=0,usecols=[1])

# %%
plt.figure()
plt.grid()
#plt.xticks(np.arange(-10, 20, step=1))
#plt.yticks(np.arange(4, 20, step=1))
plt.xlabel('Frecuencia [GHz]')
plt.ylabel('$|s_{21}|$ [dB]')
plt.plot(filts21_freq*1e-9,filts21_dB,linewidth=0.7)
#plt.legend()
plt.tight_layout()
plt.show()
plt.savefig('FiltS21.pdf',bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
AmpSparamsMag_freq=np.loadtxt("AmpSparamsMag.csv",delimiter=",",skiprows=0,usecols=[0])
AmpSparamsMag_s11=np.loadtxt("AmpSparamsMag.csv",delimiter=",",skiprows=0,usecols=[1])
AmpSparamsMag_s12=np.loadtxt("AmpSparamsMag.csv",delimiter=",",skiprows=0,usecols=[2])
AmpSparamsMag_s21=np.loadtxt("AmpSparamsMag.csv",delimiter=",",skiprows=0,usecols=[3])
AmpSparamsMag_s22=np.loadtxt("AmpSparamsMag.csv",delimiter=",",skiprows=0,usecols=[4])

# %%
f,axarr = plt.subplots(4, sharex = True, figsize = (5,12.5))
for ax in axarr:
    ax.grid()
#axarr[0].set_title('Magnitud de los parámetros de scattering')
axarr[0].plot(AmpSparamsMag_freq*1e-9,AmpSparamsMag_s11)
p=np.append(np.arange(1, 4.5, step=0.5),2.1)
axarr[0].set_xticks(np.delete(p,2))
#axarr[0].text(8.5,-5,r'$|s_{11}|$',fontsize=15,bbox=dict(boxstyle="square",color="white"))
axarr[0].set_ylabel('$|s_{11}|$ [dB]')

axarr[1].plot(AmpSparamsMag_freq*1e-9,AmpSparamsMag_s12)
#axarr[1].text(8.5,-20,r'$|s_{12}|$',fontsize=15,bbox=dict(boxstyle="square",color="white"))
axarr[1].set_ylabel('$|s_{12}|$ [dB]')

axarr[2].plot(AmpSparamsMag_freq*1e-9,AmpSparamsMag_s21)
#axarr[2].text(8.5,-5,r'$|s_{21}|$',fontsize=15,bbox=dict(boxstyle="square",color="white"))
axarr[2].set_ylabel('$|s_{21}|$ [dB]')

axarr[3].plot(AmpSparamsMag_freq*1e-9,AmpSparamsMag_s22)
#axarr[3].text(8.5,-1,r'$|s_{22}|$',fontsize=15,bbox=dict(boxstyle="square",color="white"))
axarr[3].set_ylabel('$|s_{22}|$ [dB]')
axarr[3].set_xlabel('Frecuencia (GHz)')

f.tight_layout()
f.subplots_adjust(hspace=0)


plt.savefig('AmpSparamsMag.pdf',bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="499.2">

# %%
AmpSparamsPh_freq=np.loadtxt("AmpSparamsPh.csv",delimiter=",",skiprows=0,usecols=[0])
AmpSparamsPh_s11=np.loadtxt("AmpSparamsPh.csv",delimiter=",",skiprows=0,usecols=[1])
AmpSparamsPh_s12=np.loadtxt("AmpSparamsPh.csv",delimiter=",",skiprows=0,usecols=[2])
AmpSparamsPh_s21=np.loadtxt("AmpSparamsPh.csv",delimiter=",",skiprows=0,usecols=[3])
AmpSparamsPh_s22=np.loadtxt("AmpSparamsPh.csv",delimiter=",",skiprows=0,usecols=[4])

# %%
f,axarr = plt.subplots(4, sharex = True, figsize = (5,12.5))
for ax in axarr:
    ax.grid()
#axarr[0].set_title('Magnitud de los parámetros de scattering')
axarr[0].plot(AmpSparamsPh_freq*1e-9,AmpSparamsPh_s11)
p=np.append(np.arange(1, 4.5, step=0.5),2.1)
axarr[0].set_xticks(np.delete(p,2))
#axarr[0].text(8.5,-5,r'$|s_{11}|$',fontsize=15,bbox=dict(boxstyle="square",color="white"))
axarr[0].set_ylabel(r'$\angle s_{11}$ [$^o$]')

axarr[1].plot(AmpSparamsPh_freq*1e-9,AmpSparamsPh_s12)
#axarr[1].text(8.5,-20,r'$|s_{12}|$',fontsize=15,bbox=dict(boxstyle="square",color="white"))
axarr[1].set_ylabel(r'$\angle s_{12}$ [$^o$]')

axarr[2].plot(AmpSparamsPh_freq*1e-9,AmpSparamsPh_s21)
#axarr[2].text(8.5,-5,r'$|s_{21}|$',fontsize=15,bbox=dict(boxstyle="square",color="white"))
axarr[2].set_ylabel(r'$\angle s_{21}$ [$^o$]')

axarr[3].plot(AmpSparamsPh_freq*1e-9,AmpSparamsPh_s22)
#axarr[3].text(8.5,-1,r'$|s_{22}|$',fontsize=15,bbox=dict(boxstyle="square",color="white"))
axarr[3].set_ylabel(r'$\angle s_{22}$ [$^o$]')
axarr[3].set_xlabel('Frecuencia (GHz)')

f.tight_layout()
f.subplots_adjust(hspace=0)
f.show()

plt.savefig('AmpSparamsPh.pdf',bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="499.2">

# %%
AmpTransientTens_time=np.loadtxt("AmpTransientTens.csv",delimiter=",",skiprows=0,usecols=[0])
AmpTransientTens_Vi=np.loadtxt("AmpTransientTens.csv",delimiter=",",skiprows=0,usecols=[1])
AmpTransientTens_Vo=np.loadtxt("AmpTransientTens.csv",delimiter=",",skiprows=0,usecols=[2])
AmpTransientCorr_time=np.loadtxt("AmpTransientCorr.csv",delimiter=",",skiprows=0,usecols=[0])
AmpTransientCorr_Ii=np.loadtxt("AmpTransientCorr.csv",delimiter=",",skiprows=0,usecols=[1])
AmpTransientCorr_Io=np.loadtxt("AmpTransientCorr.csv",delimiter=",",skiprows=0,usecols=[2])

# %%
plt.figure()
plt.grid()
#plt.xticks(np.arange(-10, 20, step=1))
plt.yticks(np.arange(-1, 1.25, step=0.25))
plt.xlabel('Tiempo [ns]')
plt.ylabel('Tensión [V]')
plt.plot(AmpTransientTens_time*1E-3,AmpTransientTens_Vi,linewidth=0.7,label='Tensión de entrada')
plt.plot(AmpTransientTens_time*1E-3,AmpTransientTens_Vo,linewidth=0.7,label='Tensión de salida')
plt.legend()
plt.tight_layout()
plt.show()
plt.savefig('AmpTransientTens.pdf',bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.grid()
#plt.xticks(np.arange(-10, 20, step=1))
plt.yticks(np.arange(-20, 25, step=5))
plt.xlabel('Tiempo [ns]')
plt.ylabel('Corriente [mA]')
plt.plot(AmpTransientCorr_time*1E-3,AmpTransientCorr_Ii*1E3,linewidth=0.7,label='Corriente de entrada')
plt.plot(AmpTransientCorr_time*1E-3,AmpTransientCorr_Io*1E3,linewidth=0.7,label='Corriente de salida')
plt.legend()
plt.tight_layout()
plt.show()
plt.savefig('AmpTransientCorr.pdf',bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
FiltImpedances_freq=np.loadtxt("FiltImpedances.csv",delimiter=",",skiprows=0,usecols=[0])
FiltImpedances_reZin=np.loadtxt("FiltImpedances.csv",delimiter=",",skiprows=0,usecols=[1])
FiltImpedances_imZin=np.loadtxt("FiltImpedances.csv",delimiter=",",skiprows=0,usecols=[2])
FiltImpedances_reZout=np.loadtxt("FiltImpedances.csv",delimiter=",",skiprows=0,usecols=[3])
FiltImpedances_imZout=np.loadtxt("FiltImpedances.csv",delimiter=",",skiprows=0,usecols=[4])

# %%
f,axarr = plt.subplots(2, sharex = True, figsize = (5,6))
for ax in axarr:
    ax.grid()
    ax.set_yticks(np.arange(-100,125,step=25))
#axarr[0].set_title('Magnitud de los parámetros de scattering')
axarr[0].plot(FiltImpedances_freq*1E-9,FiltImpedances_reZin,label='Re[$Z_{in}$]')
axarr[0].plot(FiltImpedances_freq*1E-9,FiltImpedances_imZin,label='Im[$Z_{in}$]')
axarr[0].legend()
#axarr[0].set_xticks(np.append(axarr[0].get_xticks(),1))
#axarr[0].text(8.5,-5,r'$|s_{11}|$',fontsize=15,bbox=dict(boxstyle="square",color="white"))
axarr[0].set_ylabel(r'$Z_{in}$ [$\Omega$]')

#axarr[0].set_title('Magnitud de los parámetros de scattering')
axarr[1].plot(FiltImpedances_freq*1E-9,FiltImpedances_reZin,label='Re[$Z_{out}$]')
axarr[1].plot(FiltImpedances_freq*1E-9,FiltImpedances_imZin,label='Im[$Z_{out}$]')
axarr[1].legend()
#axarr[0].set_xticks(np.append(axarr[0].get_xticks(),1))
#axarr[0].text(8.5,-5,r'$|s_{11}|$',fontsize=15,bbox=dict(boxstyle="square",color="white"))
axarr[1].set_ylabel(r'$Z_{out}$ [$\Omega$]')
axarr[1].set_xlabel('Frecuencia (GHz)')

f.tight_layout()
f.subplots_adjust(hspace=0)
f.savefig('FiltImpedances.pdf',bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="499.2">

# %%
AmpFiltSparamsPh_freq=np.loadtxt("AmpFiltSparamsPh.csv",delimiter=",",skiprows=0,usecols=[0])
AmpFiltSparamsPh_s11=np.loadtxt("AmpFiltSparamsPh.csv",delimiter=",",skiprows=0,usecols=[1])
AmpFiltSparamsPh_s12=np.loadtxt("AmpFiltSparamsPh.csv",delimiter=",",skiprows=0,usecols=[2])
AmpFiltSparamsPh_s21=np.loadtxt("AmpFiltSparamsPh.csv",delimiter=",",skiprows=0,usecols=[3])
AmpFiltSparamsPh_s22=np.loadtxt("AmpFiltSparamsPh.csv",delimiter=",",skiprows=0,usecols=[4])

AmpFiltSparamsMag_freq=np.loadtxt("AmpFiltSparamsMag.csv",delimiter=",",skiprows=0,usecols=[0])
AmpFiltSparamsMag_s11=np.loadtxt("AmpFiltSparamsMag.csv",delimiter=",",skiprows=0,usecols=[1])
AmpFiltSparamsMag_s12=np.loadtxt("AmpFiltSparamsMag.csv",delimiter=",",skiprows=0,usecols=[2])
AmpFiltSparamsMag_s21=np.loadtxt("AmpFiltSparamsMag.csv",delimiter=",",skiprows=0,usecols=[3])
AmpFiltSparamsMag_s22=np.loadtxt("AmpFiltSparamsMag.csv",delimiter=",",skiprows=0,usecols=[4])

# %%
f,axarr = plt.subplots(4, sharex = True, figsize = (5,12.5))
for ax in axarr:
    ax.grid()
#axarr[0].set_title('Magnitud de los parámetros de scattering')
axarr[0].plot(AmpFiltSparamsMag_freq*1e-9,AmpFiltSparamsMag_s11)
p=np.append(np.arange(0, 4.5, step=0.5),[2.1,2.6])
axarr[0].set_xticks(np.delete(p,[4,5]))
#axarr[0].text(8.5,-5,r'$|s_{11}|$',fontsize=15,bbox=dict(boxstyle="square",color="white"))
axarr[0].set_ylabel('$|s_{11}|$ [dB]')

axarr[1].plot(AmpFiltSparamsMag_freq*1e-9,AmpFiltSparamsMag_s12)
#axarr[1].text(8.5,-20,r'$|s_{12}|$',fontsize=15,bbox=dict(boxstyle="square",color="white"))
axarr[1].set_ylabel('$|s_{12}|$ [dB]')

axarr[2].plot(AmpFiltSparamsMag_freq*1e-9,AmpFiltSparamsMag_s21)
#axarr[2].text(8.5,-5,r'$|s_{21}|$',fontsize=15,bbox=dict(boxstyle="square",color="white"))
axarr[2].set_ylabel('$|s_{21}|$ [dB]')

axarr[3].plot(AmpFiltSparamsMag_freq*1e-9,AmpFiltSparamsMag_s22)
#axarr[3].text(8.5,-1,r'$|s_{22}|$',fontsize=15,bbox=dict(boxstyle="square",color="white"))
axarr[3].set_ylabel('$|s_{22}|$ [dB]')
axarr[3].set_xlabel('Frecuencia (GHz)')

f.tight_layout()
f.subplots_adjust(hspace=0)

plt.savefig('AmpFiltSparamsMag.pdf',bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="499.2">

# %%
f,axarr = plt.subplots(4, sharex = True, figsize = (5,12.5))
for ax in axarr:
    ax.grid()
#axarr[0].set_title('Magnitud de los parámetros de scattering')
axarr[0].plot(AmpFiltSparamsPh_freq*1e-9,AmpFiltSparamsPh_s11)
p=np.append(np.arange(0, 4.5, step=0.5),[2.1,2.6])
axarr[0].set_xticks(np.delete(p,[4,5]))
#axarr[0].text(8.5,-5,r'$|s_{11}|$',fontsize=15,bbox=dict(boxstyle="square",color="white"))
axarr[0].set_ylabel(r'$\angle s_{11}$ [$^o$]')

axarr[1].plot(AmpFiltSparamsPh_freq*1e-9,AmpFiltSparamsPh_s12)
#axarr[1].text(8.5,-20,r'$|s_{12}|$',fontsize=15,bbox=dict(boxstyle="square",color="white"))
axarr[1].set_ylabel(r'$\angle s_{12}$ [$^o$]')

axarr[2].plot(AmpFiltSparamsPh_freq*1e-9,AmpFiltSparamsPh_s21)
#axarr[2].text(8.5,-5,r'$|s_{21}|$',fontsize=15,bbox=dict(boxstyle="square",color="white"))
axarr[2].set_ylabel(r'$\angle s_{21}$ [$^o$]')

axarr[3].plot(AmpFiltSparamsPh_freq*1e-9,AmpFiltSparamsPh_s22)
#axarr[3].text(8.5,-1,r'$|s_{22}|$',fontsize=15,bbox=dict(boxstyle="square",color="white"))
axarr[3].set_ylabel(r'$\angle s_{22}$ [$^o$]')
axarr[3].set_xlabel('Frecuencia (GHz)')

f.tight_layout()
f.subplots_adjust(hspace=0)
f.show()

plt.savefig('AmpFiltSparamsPh.pdf',bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="499.2">

# %%
AmpFiltPot_freq=np.loadtxt("AmpFiltPot.csv",delimiter=",",skiprows=0,usecols=[0])
AmpFiltPot_dBm=np.loadtxt("AmpFiltPot.csv",delimiter=",",skiprows=0,usecols=[1])

# %%
plt.figure()
plt.grid()
p=np.append(np.arange(0, 4.5, step=0.5),[2.1,2.6])
plt.xticks(np.delete(p,[4,5]))
#plt.xticks(np.append(plt.get_xticks(),2.1))
plt.xlabel('Frecuencia [GHz]')
plt.ylabel('Potencia [dBm]')
plt.plot(AmpFiltPot_freq*1e-9,AmpFiltPot_dBm,linewidth=0.7)
#plt.legend()
plt.tight_layout()
plt.show()
plt.savefig('AmpFiltPot.pdf',bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="640">
